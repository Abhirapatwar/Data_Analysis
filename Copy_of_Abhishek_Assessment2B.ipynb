# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
os.chdir('drive/My Drive/guvi_project4')

# %%
x=pd.read_csv("college_1.csv")
x.columns.unique()
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising'],
#       dtype='object')

# %%
x
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
x.shape
# Out:
# (84, 7)

# %%
y=pd.read_csv("college_2.csv")
y.columns.unique()
# Out:
# Index(['Name', 'python', 'python_en', 'mysql', 'computational_thinking',
#        'Previous Geekions', 'CodeKata Score', 'Department', 'Rising'],
#       dtype='object')

# %%
y.shape
# Out:
# (35, 9)

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df=pd.merge(x,y,how='outer',on=['Name','Previous Geekions','python','mysql','CodeKata Score','Department', 'Rising'],right_index=False)
df.sort_values('Name', axis=0).reset_index()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:1208: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,
#      index            Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       89      Poojitha Y     0.0   35.0               7210            8970
# 1        0       A.Dharani    82.0   20.0              24500           24500
# 2       42       ABIRAMI.S    82.0    0.0               1580            1580
# 3      115      AMARNATH D    -1.0   12.0               1890            1890
# 4       84   ASHOK KUMAR K   100.0   31.0              19400           19400
# ..     ...             ...     ...    ...                ...             ...
# 114     39         vignesh    85.0    0.0               1740            1740
# 115     70       vignesh B    82.0   20.0                120             120
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
task1=df.loc[(df["CodeKata Score"]>=15000)]
task1=task1.sort_values("Name").reset_index(drop=True)
task1
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1  ASHOK KUMAR K   100.0   31.0              19400           19400
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3    V.JEEVITHA     82.0   20.0              21740           21740
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1  Electronics and Electrical Engineering       0        0.0
# 2        Computer Science and Engineering       0        NaN
# 3        Computer Science and Engineering       0        NaN
#
#    computational_thinking
# 0                     NaN
# 1                     9.0
# 2                     NaN
# 3                     NaN

# %%
task1.to_csv('Exceeded_expectations.csv')

# %%
task2=df.loc[(df["CodeKata Score"]>=10000)&(df["CodeKata Score"]<=15000)]
task2=task2.sort_values("Name").reset_index(drop=True)
task2
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    Bodipudi Harini    -1.0   35.0              10040           10040
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3        Mugunthan S   100.0   47.0              10610           10610
#
#                                   Department  Rising  python_en  \
# 0  Electronics and Communication Engineering       0        0.0
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3           Computer Science and Engineering       0        NaN
#
#    computational_thinking
# 0                    -1.0
# 1                     0.0
# 2                     6.0
# 3                     NaN

# %%
task2.to_csv('Reached_expectations.csv')

# %%
task3=df.loc[(df["CodeKata Score"]>=7000)&(df["CodeKata Score"]<=10000)]
task3=task3.sort_values("CodeKata Score",ascending=False).reset_index(drop=True)
task3
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0                VIINU V P    -1.0   24.0               9150            9150
# 1              Sathammai.S   100.0    8.0               8980            8980
# 2               Poojitha Y     0.0   35.0               7210            8970
# 3   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 4                Gowtham R    -1.0    4.0               8650            8650
# 5                 shifak N    58.0    0.0               5180            8320
# 6             NIVEESHWAR S   100.0    0.0               8200            8200
# 7                  Balaji     -1.0   20.0               6170            8160
# 8                 Rushitha    -1.0   62.0               7470            8090
# 9     Balaraman Muthupandi    -1.0    0.0               7670            8050
# 10                JPradhap   100.0    0.0               7340            8030
# ...

# %%
task3.to_csv('Needs_Improvement.csv')

# %%
task4=df.loc[(df["CodeKata Score"]<=7000)]
task4=task4.sort_values("CodeKata Score",ascending=False).reset_index(drop=True)
task4
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0   Narasimhan Y L    -1.0    0.0               4800            6800
# 1     Leelakrishna    -1.0    4.0               5300            6640
# 2   PremsagarReddy    -1.0    0.0               5290            6290
# 3        pradeeban    16.0   24.0               6060            6090
# 4       J.SUGANTHI    27.0   50.0               5860            5860
# ..             ...     ...    ...                ...             ...
# 88   N.Ajith kumar    82.0    0.0                  0               0
# 89        BARATH.P    29.0    0.0                  0               0
# 90    KarthikeyanS    45.0    0.0                  0               0
# 91            XY Z    -1.0   -1.0                  0               0
# 92       Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering    2000       -1.0
# ...

# %%
task4.to_csv('Unsatisfactory.csv')

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
u=np.mean(df["Previous Geekions"])
np.round_(u,decimals=2)
# Out:
# 3842.35

# %%
u=np.mean(df["CodeKata Score"])
np.round_(u,decimals=2)
# Out:
# 4051.76

# %%
u=df["Previous Geekions"].mean(axis=0)
np.round_(u,decimals=2)
# Out:
# 3842.35

# %%
u=df["CodeKata Score"].mean(axis=0)
np.round_(u,decimals=2)
# Out:
# 4051.76

# %% [markdown]
# ###### No of students participated

# %%
df.Name.size
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
o=df.loc[(df.python==100)|(df.mysql==100)|(df.python_en==100)|(df["computational_thinking"]==100)]
o.shape[0]
# Out:
# 46

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(3,"CodeKata Score")
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(3,"Previous Geekions")
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df.Department.unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
import seaborn as sns
colors = sns.color_palette('pastel')[0:5]

# %%
d=df.groupby(["Department"])["CodeKata Score"].sum()
d
# Out:
# Department
# Computer Science and Engineering             320025
# Electronics and Communication Engineering    108335
# Electronics and Electrical Engineering        53800
# Name: CodeKata Score, dtype: int64

# %%
l=[]
l2=["Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering "]
c=df.groupby(["Department"])["CodeKata Score"].sum()
for i in range(c.shape[0]):
  l.append(c[i])

# %%
plt.pie(l,labels=l2,colors=colors,autopct='%.0f%%',wedgeprops={"linewidth":0.5,"edgecolor":"grey"})
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
j=df.groupby(["Department"])["CodeKata Score"].nlargest(3)
j
# Out:
# Department
# Computer Science and Engineering           0     24500
#                                            1     21740
#                                            2     19680
# Electronics and Communication Engineering  87    10040
#                                            91     8650
#                                            6      7880
# Electronics and Electrical Engineering     84    19400
#                                            88     9150
#                                            92     8320
# Name: CodeKata Score, dtype: int64

# %%
j.unstack(level=-1)
# Out:
#                                                 0        1        2       6   \
# Department
# Computer Science and Engineering           24500.0  21740.0  19680.0     NaN
# Electronics and Communication Engineering      NaN      NaN      NaN  7880.0
# Electronics and Electrical Engineering         NaN      NaN      NaN     NaN
#
#                                                 84       87      88      91  \
# Department
# Computer Science and Engineering               NaN      NaN     NaN     NaN
# Electronics and Communication Engineering      NaN  10040.0     NaN  8650.0
# Electronics and Electrical Engineering     19400.0      NaN  9150.0     NaN
#
#                                                92
# Department
# Computer Science and Engineering              NaN
# Electronics and Communication Engineering     NaN
# Electronics and Electrical Engineering     8320.0

# %%
l1=["Computer Science and Engineering","Electronics and Communication Engineering","Electronics and Electrical Engineering"]

m=[]
for u in l1:
  l2=[]
  for i in range(93):
    try:
      if j[u][i]!=np.NaN:
        l2.append(j[u][i])
      else:
        continue
    except:
      None    
  l2.sort()
  l2.reverse()     
  m.append(l2)

# %%
m
# Out:
# [[24500, 21740, 19680], [10040, 8650, 7880], [19400, 9150, 8320]]

# %%
x = np.arange(len(l1))
width=0.20
plt.figure(figsize=(10,5))
plt.bar(x, m[0], width, label='Computer Science')
plt.bar(x+width, m[1], width, label='Electronics and Communication')
plt.bar(x+width+width, m[2], width, label='Electronics and Electrical')
plt.legend()
plt.show()
